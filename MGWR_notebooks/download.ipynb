# %%
# !tar chvfz notebook.tar.gz *
# Out:
# HIV_NYC_DIF.ipynb
# HIV_NYC_GWR.csv
# MGWR_HIV_log_transform.ipynb
# MGWR_HIV_visualization.ipynb
# Mapping_MGWR_results_shared.ipynb
# download.ipynb
# spatialindex-src-1.8.5/
# spatialindex-src-1.8.5/test/
# spatialindex-src-1.8.5/test/rtree/
# spatialindex-src-1.8.5/test/rtree/test2/
# spatialindex-src-1.8.5/test/rtree/test2/run
# spatialindex-src-1.8.5/test/rtree/test4/
# spatialindex-src-1.8.5/test/rtree/test4/run
# spatialindex-src-1.8.5/test/rtree/test1/
# spatialindex-src-1.8.5/test/rtree/test1/run
# spatialindex-src-1.8.5/test/rtree/test3/
# spatialindex-src-1.8.5/test/rtree/test3/run
# spatialindex-src-1.8.5/test/rtree/Generator.cc
# spatialindex-src-1.8.5/test/rtree/RTreeQuery.cc
# spatialindex-src-1.8.5/test/rtree/Makefile.am
# spatialindex-src-1.8.5/test/rtree/Exhaustive.cc
# spatialindex-src-1.8.5/test/rtree/RTreeBulkLoad.cc
# spatialindex-src-1.8.5/test/rtree/Makefile.in
# spatialindex-src-1.8.5/test/rtree/RTreeLoad.cc
# spatialindex-src-1.8.5/test/rtree/Makefile
# ...
